# %%
import pandas as pd
import requests
import json

# %%
combined_data = pd.DataFrame()
file_paths = ["C:\CRUV\search_engine_api\search_api\services\data\input\college_degree.csv"]

# %%
for file_path in file_paths:
    df = pd.read_csv(file_path)
    combined_data = pd.concat([combined_data, df], ignore_index=True)

# %%
combined_data
# Out:
#                                           degree_title
# 0                            Bachelor of Architecture   \
# 1                                    Bachelor of Arts
# 2                            Bachelor of Applied Arts
# 3                Bachelor of Applied Arts and Science
# 4    Bachelor of Applied Science in Information Tec...
# ..                                                 ...
# 165                                 Master of Studies
# 166                                Master of Theology
# 167                     Master of Theological Studies
# 168                           Master of Urban Planning
# 169                      Master of Veterinary Science
#
#                                 degree_reference degree_level
# 0                                      ['BArch']     bachelor
# 1    ['BA', ' AB', ' BS', ' BSc', ' SB', ' ScB']     bachelor
# 2                                        ['BAA']     bachelor
# ...

# %%
def seed_subjects(row):
    url = "http://127.0.0.1:8000/profile/save/degree"
    data = {
        "name": row["degree_title"],
        "education_level": row["degree_level"]
    }
    
    headers = {
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))
    print(response.status_code)
    print(response.json())

# %%
combined_data.apply(seed_subjects, axis=1)
# Out:
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '1', 'attributes': {'name': 'Bachelor of Architecture', 'education_level': 'bachelor'}}}
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '2', 'attributes': {'name': 'Bachelor of Arts', 'education_level': 'bachelor'}}}
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '3', 'attributes': {'name': 'Bachelor of Applied Arts', 'education_level': 'bachelor'}}}
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '4', 'attributes': {'name': 'Bachelor of Applied Arts and Science', 'education_level': 'bachelor'}}}
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '5', 'attributes': {'name': 'Bachelor of Applied Science in Information Technology', 'education_level': 'bachelor'}}}
# 201
# {'data': {'type': 'SaveDegreeAPIView', 'id': '6', 'attributes': {'name': 'Bachelor of Design', 'education_level': 'bachelor'}}}
# 201
# ...
