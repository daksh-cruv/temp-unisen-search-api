# %%
import pandas as pd
import requests
import json

# %%
combined_data = pd.DataFrame()
file_paths = ["C:\\CRUV\\search_engine_api\\drf_course\\backend\\services\\data\\input\\college_majors.csv"]

# %%
for file_path in file_paths:
    df = pd.read_csv(file_path)
    combined_data = pd.concat([combined_data, df], ignore_index=True)

# %%
combined_data
# Out:
#                                        Major Major_Category
# 0                        GENERAL AGRICULTURE    Agriculture
# 1      AGRICULTURE PRODUCTION AND MANAGEMENT    Agriculture
# 2                     AGRICULTURAL ECONOMICS    Agriculture
# 3                            ANIMAL SCIENCES    Agriculture
# 4                               FOOD SCIENCE    Agriculture
# ..                                       ...            ...
# 414        Mechanical Engineering Technology    Engineering
# 415                    Military Technologies    Engineering
# 416                      Nuclear Engineering    Engineering
# 417  Quality Control and Safety Technologies    Engineering
# 418                     Surveying Technology    Engineering
#
# [419 rows x 2 columns]

# %%
def seed_subjects(row):
    url = "http://127.0.0.1:8000/profile/save/major"
    data = {
        "name": row["Major"],
        "category": row["Major_Category"]
    }
    
    headers = {
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))
    print(response.status_code)
    print(response.json())

# %%
combined_data.apply(seed_subjects, axis=1)
# Out:
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '1', 'attributes': {'name': 'GENERAL AGRICULTURE'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '2', 'attributes': {'name': 'AGRICULTURE PRODUCTION AND MANAGEMENT'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '3', 'attributes': {'name': 'AGRICULTURAL ECONOMICS'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '4', 'attributes': {'name': 'ANIMAL SCIENCES'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '5', 'attributes': {'name': 'FOOD SCIENCE'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '6', 'attributes': {'name': 'PLANT SCIENCE AND AGRONOMY'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '7', 'attributes': {'name': 'SOIL SCIENCE'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '8', 'attributes': {'name': 'MISCELLANEOUS AGRICULTURE'}}}
# 201
# {'data': {'type': 'SaveMajorAPIView', 'id': '9', 'attributes': {'name': 'FORESTRY'}}}
# 201
# ...
